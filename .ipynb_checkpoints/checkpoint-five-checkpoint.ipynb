# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset: https://github.com/mysciaroni/pokemon-tcg-data.git
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

con=sqlite3.connect("database\pokemon-tcg-database.sqlite3")
action = pd.read_csv('data\Action.txt', delimiter='\t')
action
# Out:
#       id_action  id_action_type                name  \
# 0             1               1              [Bear]
# 1             2               1             [Chase]
# 2             3               1            [Engage]
# 3             4               1              [Find]
# 4             5               1              [Give]
# ...         ...             ...                 ...
# 1773       1774               4              Sturdy
# 1774       1775               4          Metal Skin
# 1775       1776               4  Antibacterial Skin
# 1776       1777               4           Final Dig
# 1777       1778               4         Flying Taxi
#
#                                                    text
# 0     Once during your turn (before your attack), yo...
# 1     As long as Unown C is your Active Pokémon, whe...
# 2     When you play Unown E from your hand, your opp...
# 3     Once during your turn (before you attack), if ...
# ...

# %%
pokedex = pd.read_csv('data\pokedex.txt', delimiter='\t')
pokedex
# Out:
#      id_pokedex  id_pokemon_region  region_number  national_index  \
# 0             1                  1              1               1
# 1             2                  1              2               2
# 2             3                  1              3               3
# 3             4                  1              4               4
# 4             5                  1              5               5
# ..          ...                ...            ...             ...
# 949         950                 10              0             897
# 950         951                 10              0             898
# 951         952                 10              0             898
# 952         953                 10              0             898
# 953         954                 10              0             898
#
#     alternative_name        name  id_pokedex_type_1  id_pokedex_type_2  \
# 0          Bulbasaur   Bulbasaur                 11               15.0
# ...

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
sns.pairplot(action, x_vars = ['id_action_type', 'name'], 
             y_vars = 'id_action', size=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(action.corr(), cmap='YlGnBu', annot = True)
plt.show()

# %%
sns.pairplot(pokedex, x_vars = ['region_number', 'id_generation'], 
             y_vars = 'national_index', size=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(pokedex.corr(), cmap='YlGnBu', annot = True)
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %%
x=pokedex['id_pokedex']
y=pokedex['id_generation']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.7, 
                                                    test_size = 0.3, random_state=100)

# %%
x_train
# Out:
# 105    106
# 953    954
# 299    300
# 69      70
# 85      86
#       ...
# 855    856
# 871    872
# 835    836
# 792    793
# 520    521
# Name: id_pokedex, Length: 667, dtype: int64

# %%
y_train
# Out:
# 105    1
# 953    8
# 299    3
# 69     1
# 85     1
#       ..
# 855    7
# 871    8
# 835    7
# 792    7
# 520    4
# Name: id_generation, Length: 667, dtype: int64

# %%
import statsmodels.api as sm
x_train_sm = sm.add_constant(x_train)

# %%
lr=sm.OLS(y_train, x_train_sm).fit()
lr.params
# Out:
# const         0.265659
# id_pokedex    0.008081
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          id_generation   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                 2.596e+04
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):               0.00
# Time:                        23:34:35   Log-Likelihood:                -265.37
# No. Observations:                 667   AIC:                             534.7
# Df Residuals:                     665   BIC:                             543.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2657      0.028      9.471      0.000       0.211       0.321
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 0.2657 + 0.0081*x_train, 'r')
plt.show()

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %%
y_train_pred = lr.predict(x_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.displot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train-y_train_pred', fontsize = 15)
plt.show()

# %%
plt.scatter(x_train, res)
plt.show()

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.638
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case.
# 3. Was your plot of the error terms a bell curve? Not really
